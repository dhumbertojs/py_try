# %%
import pandas as pd

# %%
tabla=pd.read_excel("ProgramaciondeServicioMod1.xlsx", index_col=0, sheet_name="Tabla Base de PS", header=1)
pd.DataFrame.head(tabla)
# Out:
#      RANGO HORARIO   Px  Frecuencia (f)  Intervalo (i)  \
# NaN    6:00 - 7:00   69        0.851852      70.434783
# NaN    7:00 - 8:00  133        1.641975      36.541353
# NaN    8:00 - 9:00  130        1.604938      37.384615
# NaN   9:00 - 10:00  160        1.975309      30.375000
# NaN  10:00 - 11:00   84        1.037037      57.857143
#
#      TIEMPO DE RECORRIDO T1 a T2  TIEMPO DE RECORRIDO T2 a T1  \
# NaN                           22                           40
# NaN                           26                           41
# NaN                           24                           41
# NaN                           29                           38
# NaN                           30                           38
#
#      TIEMPO EN TERMINAL 1  TIEMPO EN TERMINAL 2  TIEMPO DE CICLO (TC)  \
# NaN                     2                     4                    68
# NaN                     3                     4                    74
# ...

# %%
fin=pd.read_excel("ProgramaciondeServicioMod1.xlsx", index_col=0, sheet_name="Programación del profe", header=2)
pd.DataFrame.head(fin)
# Out:
#      CORRIDA HORA DE PRESENTACION DEL CHOFER ENCIERRO SALIDA HORA DE LLEGADA  \
# NaN        1                        05:28:00        05:38:00        05:58:00
# NaN        1                             NaN             NaN        07:06:00
# NaN        2                        07:14:00        07:24:00        07:44:00
# NaN        1                             NaN             NaN        08:21:00
# NaN        2                             NaN             NaN        08:58:00
#
#     HORA DE SALIDA HORA DE LLEGADA.1 HORA DE SALIDA.1
# NaN       06:00:00          06:22:00         06:26:00
# NaN       07:10:00          07:36:00         07:40:00
# NaN       07:47:00          08:13:00         08:17:00
# NaN       08:24:00          08:48:00         08:52:00
# NaN       09:01:00          09:30:00         09:34:00
